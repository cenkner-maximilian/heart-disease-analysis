# %% [markdown]
# <h1>📊 COMPLETE ANALYSIS OVERVIEW</h1>
# <i>💡 Below, you can see my entire analysis, enhanced by comments explaining my thinking process</i>

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update(plt.rcParamsDefault)

# %%
heart_data = pd.read_csv("heart_disease.csv")
heart_data.dropna(inplace=True)

heart_data
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# 5     25.0    Male           152.0              257.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9992  68.0  Female           169.0              291.0          Medium     Yes
# 9994  73.0  Female           144.0              191.0          Medium     Yes
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %% [markdown]
# **<h5>Key analysis goals devised from dataset:</h5>**
#
# 1. Is there any correlation between the following variables?
#     1. Sleep Hours vs Blood Pressure
#     2. Sleep Hours vs Cholesterol Level
# 2. Does Heart Disease in family increase the possibility of heart disease?
# 3. Do high/low levels of Homocysteine cause Heart disease?
#
# ***These questions will be answered below.***
